# %% [markdown]
# # **Proyek Analisis Data : Air_Quality_Shunyi**
#
# Nama : Fikri Alinfijar
#
# Email : fikrialnfjr@gmail.com
#
# Id Dicoding : fikrialnfjr

# %% [markdown]
# ## Pertanyaan Bisnis
#
# 1. Bagaimana kualitas udara di Shunyi berdasarkan PM2.5 setiap tahunnya?
#
# 2. Apakah terdapat pola musiman pada kualitas udara Shunyi setiap tahunnya berdasarkan PM10?

# %% [markdown]
# ## Library

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import KMeans

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Gathering Data

# %%
df = pd.read_csv('Air_Quality_Shunyi.csv')
df = df.drop(columns=['No', 'RAIN', 'wd', 'station'])
df
# Out:
#        year  month  day  hour  PM2.5  PM10   SO2   NO2      CO    O3  TEMP
# 0      2013      3    1     0    3.0   6.0   3.0   8.0   300.0  44.0  -0.9  \
# 1      2013      3    1     1   12.0  12.0   3.0   7.0   300.0  47.0  -1.1
# 2      2013      3    1     2   14.0  14.0   NaN   7.0   200.0  22.0  -1.7
# 3      2013      3    1     3   12.0  12.0   3.0   5.0     NaN   NaN  -2.1
# 4      2013      3    1     4   12.0  12.0   3.0   NaN   200.0  11.0  -2.4
# ...     ...    ...  ...   ...    ...   ...   ...   ...     ...   ...   ...
# 35059  2017      2   28    19   27.0  72.0   8.0  92.0   800.0  16.0  10.3
# 35060  2017      2   28    20   47.0  55.0  17.0  86.0  1100.0  19.0   9.8
# 35061  2017      2   28    21   18.0  28.0   4.0  30.0   500.0  64.0   9.1
# 35062  2017      2   28    22   18.0  20.0   9.0  33.0   500.0  59.0   7.1
# 35063  2017      2   28    23   15.0  22.0  13.0  34.0   500.0  60.0   7.4
#
#          PRES  DEWP  WSPM
# 0      1025.8 -20.5   9.3
# 1      1026.1 -21.3   9.4
# 2      1026.2 -23.0   8.6
# 3      1027.3 -23.3   6.6
# 4      1027.7 -22.9   4.5
# ...       ...   ...   ...
# 35059  1014.2 -12.4   1.8
# 35060  1014.5  -9.9   1.5
# 35061  1014.6 -12.7   1.7
# 35062  1015.2 -13.2   1.8
# 35063  1014.9 -11.9   1.4
#
# [35064 rows x 14 columns]

# %% [markdown]
# ### Assessing Data

# %% [markdown]
# #### Info Dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 14 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   year    35064 non-null  int64
#  1   month   35064 non-null  int64
#  2   day     35064 non-null  int64
#  3   hour    35064 non-null  int64
#  4   PM2.5   34151 non-null  float64
#  5   PM10    34516 non-null  float64
#  6   SO2     33768 non-null  float64
#  7   NO2     33699 non-null  float64
#  8   CO      32886 non-null  float64
#  9   O3      33575 non-null  float64
#  10  TEMP    35013 non-null  float64
#  11  PRES    35013 non-null  float64
#  12  DEWP    35010 non-null  float64
#  13  WSPM    35020 non-null  float64
# dtypes: float64(10), int64(4)
# memory usage: 3.7 MB

# %% [markdown]
# #### Pengecekan Ukuran Dataset

# %%
df.shape
# Out:
# (35064, 14)

# %% [markdown]
# #### Pengecekan Missing Value

# %%
df.isnull().sum()
# Out:
# year        0
# month       0
# day         0
# hour        0
# PM2.5     913
# PM10      548
# SO2      1296
# NO2      1365
# CO       2178
# O3       1489
# TEMP       51
# PRES       51
# DEWP       54
# WSPM       44
# dtype: int64

# %% [markdown]
# #### Pengecekan Outliers

# %%
Q1 = df.quantile(0.25)
Q3 = df.quantile(0.75)
IQR = Q3 - Q1

# Menghitung batas atas dan batas bawah untuk outlier
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Mengidentifikasi outlier
outliers = ((df < lower_bound) | (df > upper_bound)).sum()

print(outliers)
# Out:
# year        0
# month       0
# day         0
# hour        0
# PM2.5    1501
# PM10     1180
# SO2      3011
# NO2       579
# CO       1969
# O3       1562
# TEMP        0
# PRES        0
# DEWP        0
# WSPM     1984
# dtype: int64

# %% [markdown]
# #### Menampilkan Outliers dalam Bentuk Boxplot

# %%
# Membuat box plot untuk setiap kolom
plt.figure(figsize=(12, 6))  # Ukuran plot bisa disesuaikan
df.boxplot()
plt.title('Box Plot untuk Kolom Tanpa "wd" dan "station"')
plt.ylabel('Nilai')
plt.xticks(rotation=45)  # Melabeli sumbu x dengan rotasi teks
plt.show()

# %% [markdown]
# ### Cleaning Data

# %% [markdown]
# #### Menangani Missing Value

# %%
# Mengisi missing value dengan mean untuk kolom-kolom numerik
kolom_numerik = df.select_dtypes(include=['int', 'float'])
df[kolom_numerik.columns] = df[kolom_numerik.columns].fillna(df[kolom_numerik.columns].mean())

# Mengisi missing value dengan modus untuk kolom objek jika mode() tidak kosong
kolom_objek = df.select_dtypes(include=['object'])
if not kolom_objek.empty:
    df[kolom_objek.columns] = df[kolom_objek.columns].fillna(df[kolom_objek.columns].mode().iloc[0])

# %% [markdown]
# #### Pengecekan Jumlah Missing Value Setelah Penanganan

# %%
df.isnull().sum()
# Out:
# year     0
# month    0
# day      0
# hour     0
# PM2.5    0
# PM10     0
# SO2      0
# NO2      0
# CO       0
# O3       0
# TEMP     0
# PRES     0
# DEWP     0
# WSPM     0
# dtype: int64

# %% [markdown]
# #### Menangani Outliers

# %%
# Menghapus baris yang mengandung outliers berdasarkan batas atas dan bawah
df_cleaned = df[(df >= lower_bound) & (df <= upper_bound)].dropna()

# Menampilkan DataFrame setelah menghapus outliers
print(df_cleaned)
# Out:
#        year  month  day  hour  PM2.5  PM10   SO2   NO2      CO    O3  TEMP
# 5      2013      3    1     5   11.0  11.0   3.0   7.0   200.0  45.0  -2.8  \
# 6      2013      3    1     6   12.0  12.0   3.0   9.0   300.0  74.0  -4.0
# 7      2013      3    1     7   13.0  13.0   3.0  23.0   300.0  59.0  -2.4
# 8      2013      3    1     8    8.0   8.0   3.0  19.0   400.0  66.0  -1.0
# 9      2013      3    1     9    3.0   6.0   3.0  21.0   400.0  60.0   0.0
# ...     ...    ...  ...   ...    ...   ...   ...   ...     ...   ...   ...
# 35059  2017      2   28    19   27.0  72.0   8.0  92.0   800.0  16.0  10.3
# 35060  2017      2   28    20   47.0  55.0  17.0  86.0  1100.0  19.0   9.8
# 35061  2017      2   28    21   18.0  28.0   4.0  30.0   500.0  64.0   9.1
# 35062  2017      2   28    22   18.0  20.0   9.0  33.0   500.0  59.0   7.1
# 35063  2017      2   28    23   15.0  22.0  13.0  34.0   500.0  60.0   7.4
#
#          PRES  DEWP  WSPM
# 5      1028.2 -22.1   1.7
# 6      1029.0 -21.2   1.6
# 7      1030.5 -21.3   1.7
# 8      1031.2 -21.8   2.7
# 9      1031.3 -22.9   0.8
# ...       ...   ...   ...
# 35059  1014.2 -12.4   1.8
# 35060  1014.5  -9.9   1.5
# 35061  1014.6 -12.7   1.7
# 35062  1015.2 -13.2   1.8
# 35063  1014.9 -11.9   1.4
#
# [26892 rows x 14 columns]

# %% [markdown]
# #### Pengecekan Jumlah Outliers Setelah Penanganan

# %%
# Menghitung jumlah outliers setelah penghapusan
outliers_sesudah = ((df_cleaned < lower_bound) | (df_cleaned > upper_bound)).sum()

# Menampilkan jumlah outliers setelah penghapusan
print(outliers_sesudah)
# Out:
# year     0
# month    0
# day      0
# hour     0
# PM2.5    0
# PM10     0
# SO2      0
# NO2      0
# CO       0
# O3       0
# TEMP     0
# PRES     0
# DEWP     0
# WSPM     0
# dtype: int64

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# #### Menyimpan Data Bersih ke dalam Variabel df

# %%
df = df_cleaned

# %% [markdown]
# #### Statistik Deskriptif

# %%
df.describe()
# Out:
#                year         month           day          hour         PM2.5
# count  26892.000000  26892.000000  26892.000000  26892.000000  26892.000000  \
# mean    2014.669567      6.707906     15.755318     10.984494     60.662873
# std        1.169947      3.259543      8.811826      7.015626     51.946312
# min     2013.000000      1.000000      1.000000      0.000000      2.000000
# 25%     2014.000000      4.000000      8.000000      5.000000     18.000000
# 50%     2015.000000      7.000000     16.000000     10.000000     47.000000
# 75%     2016.000000      9.000000     23.000000     17.000000     86.000000
# max     2017.000000     12.000000     31.000000     23.000000    251.000000
#
#                PM10           SO2           NO2            CO            O3
# count  26892.000000  26892.000000  26892.000000  26892.000000  26892.000000  \
# mean      77.233776      8.555768     39.382479    918.363387     49.773770
# std       59.079423      8.893103     24.494103    615.539934     41.223363
# min        2.000000      0.285600      2.000000    100.000000      0.214200
# 25%       27.000000      2.000000     20.000000    400.000000     13.000000
# 50%       65.000000      4.000000     36.000000    800.000000     46.000000
# 75%      113.000000     13.000000     54.000000   1200.000000     72.000000
# max      298.000000     39.000000    126.000000   3100.000000    177.000000
#
#                TEMP          PRES          DEWP          WSPM
# count  26892.000000  26892.000000  26892.000000  26892.000000
# mean      14.122202   1012.729474      3.657272      1.597676
# std       10.965006     10.116390     13.749323      0.892563
# min      -15.000000    988.000000    -33.100000      0.000000
# 25%        4.700000   1004.500000     -8.000000      1.000000
# 50%       16.000000   1012.000000      5.600000      1.400000
# 75%       23.300000   1020.500000     16.000000      2.100000
# max       37.800000   1042.800000     27.500000      4.200000

# %% [markdown]
# #### Korelasi

# %%
# Matriks korelasi
corr_matrix = df.corr()

# Visualisasi matriks korelasi
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Matriks Korelasi')
plt.show()

# %% [markdown]
# #### Persebaran Data

# %%
#persebaran data
kolom_persebaran = ["PM2.5", "PM10", "SO2", "NO2", "CO", "O3", "TEMP", "PRES", "DEWP", "WSPM"]

# Membuat subplots dengan grid 2x5
fig, axes = plt.subplots(nrows=2, ncols=5, figsize=(16, 8))

# Menampilkan histogram untuk setiap kolom
for i, kolom in enumerate(kolom_persebaran):
    row = i // 5
    col = i % 5
    axes[row, col].hist(df[kolom], bins=30, color='skyblue', alpha=0.7)
    axes[row, col].set_title(f'Histogram {kolom}')
    axes[row, col].set_xlabel(kolom)
    axes[row, col].set_ylabel('Frekuensi')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Pertanyaan 1
#
# #### Bagaimana kualitas udara di Shunyi berdasarkan PM2.5 setiap tahunnya?

# %%
rata2_pm25_per_tahun = df.groupby('year')['PM2.5'].mean()

plt.figure(figsize=(10, 6))
plt.plot(rata2_pm25_per_tahun.index, rata2_pm25_per_tahun.values, marker='o', linestyle='-')
plt.title('Rata-rata PM2.5 berdasarkan Tahun')
plt.xlabel('Tahun')
plt.ylabel('Rata-rata PM2.5')
plt.grid(True)

# Menambahkan label untuk setiap titik
for i, txt in enumerate(rata2_pm25_per_tahun.values):
    plt.text(rata2_pm25_per_tahun.index[i], txt, f'{txt:.2f}', ha='right', va='bottom')

plt.show()

# %% [markdown]
# ##### Kesimpulan :
#
# Dari grafik terebut, didapatkan bahwa rata-rata PM2.5 pada Shunyi setiap tahunnya selalu berada diatas 40 mikrogram per meter kubik.
# Hal tersebut dapat diartikan bahwa kualitas udara di Shunyi buruk, karena menurut WHO batas ambang untuk PM2.5 adalah 15 mikrogram per meter kubik.

# %% [markdown]
# ### Pertanyaan 2
#
# #### Apakah terdapat pola pergerakan pada kualitas udara Shunyi setiap tahunnya berdasarkan PM10?

# %%
rata2_pm10_per_tahun_bulan = df.groupby(['year', 'month'])['PM10'].mean()
rata2_pm10_per_tahun_bulan.index = rata2_pm10_per_tahun_bulan.index.map(lambda x: f'{x[0]}-{x[1]:02}')

plt.figure(figsize=(14, 6))
plt.plot(rata2_pm10_per_tahun_bulan.index, rata2_pm10_per_tahun_bulan.values, marker='o', linestyle='-')
plt.title('Rata-rata PM10 berdasarkan Bulan di Setiap Tahun')
plt.xlabel('Tahun dan Bulan')
plt.ylabel('Rata-rata PM10')
plt.xticks(rotation=45) 
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### Kesimpulan :
#
# Dari grafik tersebut, didapatkan bahwa terdapat pola pergerakan dimana pada bulan ke-12 rata-rata PM10 hampir selalu berada dibawah, kemudian rata-rata tersebut naik lagi hingga bulan ke-4

# %% [markdown]
# ## Analisis Regresi

# %%
import pandas as pd
import statsmodels.api as sm

# Membaca dataset dari file CSV
df = pd.read_csv("Shunyi_clean_data.csv")

# Memilih variabel independen (X) dan variabel dependen (y)
X = df[['TEMP']]  # Variabel independen: suhu udara
y = df['PM2.5']   # Variabel dependen: konsentrasi PM2.5

# Menambahkan konstanta ke variabel independen (X) untuk estimasi bias
X = sm.add_constant(X)

# Membuat model regresi
model = sm.OLS(y, X).fit()

# Mencetak ringkasan model
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  PM2.5   R-squared:                       0.006
# Model:                            OLS   Adj. R-squared:                  0.006
# Method:                 Least Squares   F-statistic:                     154.0
# Date:                Fri, 01 Mar 2024   Prob (F-statistic):           2.93e-35
# Time:                        05:12:55   Log-Likelihood:            -1.4123e+05
# No. Observations:               26428   AIC:                         2.825e+05
# Df Residuals:                   26426   BIC:                         2.825e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         54.4607      0.510    106.816      0.000      53.461      55.460
# TEMP           0.3535      0.028     12.409      0.000       0.298       0.409
# ==============================================================================
# Omnibus:                     4412.517   Durbin-Watson:                   0.151
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             7025.061
# Skew:                           1.171   Prob(JB):                         0.00
# Kurtosis:                       3.945   Cond. No.                         29.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# Dari summary tersebut didapatkan bahwa :
#
# - Model regresi yang dibangun menunjukkan bahwa terdapat hubungan yang signifikan antara variabel dependen (PM2.5) dan variabel independen (TEMP).
#
# - Koefisien regresi untuk variabel TEMP adalah 0.3535, dengan nilai p yang sangat rendah (< 0.001), menunjukkan bahwa terdapat hubungan yang signifikan antara suhu udara dan konsentrasi PM2.5.
#
# - Interval kepercayaan 95% untuk koefisien regresi TEMP tidak mencakup nol, menunjukkan bahwa kita cukup yakin bahwa efek suhu udara terhadap konsentrasi PM2.5 tidak nol.
#
# #### Kesimpulan :
#
# Berdasarkan hasil ini, kita dapat menyimpulkan bahwa variabel PM2.5 bergantung pada variabel TEMP. Dengan kata lain, konsentrasi PM2.5 dipengaruhi oleh suhu udara, dan perubahan dalam suhu udara dapat memengaruhi perubahan dalam konsentrasi PM2.5. Meskipun hubungan ini signifikan secara statistik, nilai koefisien regresi yang rendah menunjukkan bahwa efek suhu udara mungkin tidak memiliki pengaruh yang besar dalam menjelaskan variasi dalam konsentrasi PM2.5.

# %% [markdown]
# ## Conclusion
#
# 1. Bagaimana kualitas udara di Shunyi berdasarkan PM2.5 setiap tahunnya?
#
#
# 2. Apakah terdapat pola pergerakan pada kualitas udara Shunyi setiap tahunnya berdasarkan PM10?

# %% [markdown]
# #### Kesimpulan :
#
# Kesimpulan dari kedua analisis tersebut adalah bahwa kualitas udara di Shunyi cenderung buruk berdasarkan rata-rata PM2.5 yang tinggi setiap tahunnya, dan terdapat pola pergerakan yang konsisten dalam kualitas udara berdasarkan PM10, dengan penurunan yang signifikan pada akhir tahun diikuti dengan kenaikan pada awal tahun berikutnya. Hal ini menunjukkan perlunya tindakan yang lebih lanjut untuk mengatasi masalah polusi udara di Shunyi, serta untuk memantau secara aktif perubahan musiman dalam kualitas udara untuk mengambil langkah-langkah yang sesuai dalam pengelolaan lingkungan dan kesehatan masyarakat.
